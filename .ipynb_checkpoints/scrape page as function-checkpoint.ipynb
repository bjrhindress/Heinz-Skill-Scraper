# %%
#define function that scrapes one page at a time and returns a panda dataframe
def scrape_page(page_num):
    import requests  # b_soup_1.py
    import re
    from bs4 import BeautifulSoup
    #spoof the user agent to make page scrapable
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
#define position search term (one word) and location
    position='analyst'
    location='Pittsburgh,+PA'
    page_str=str(page_num)
#url for search query
    url='https://www.indeed.com/jobs?q='+position+'&l='+location+'&start='+page_str
    search_page=requests.get(url,headers=headers)
    search_page
    soup=BeautifulSoup(search_page.content,'html.parser')
    all_cards=soup.find_all(class_='jobsearch-SerpJobCard row result')
#empty list to store job posting urls
    job_urls=[]
#it seems to be easier to pull posting dates and locations from search page, so do that here
    posting_dates=[]
    locations=[]
#iterate through all_cards, extract job posting urls, posting dates, and locations
    for card in all_cards:
    #urls
        job_id=card['data-jk']
        job_url='https://www.indeed.com/viewjob?jk='+job_id
        job_urls.append(job_url)
    #posting dates
    #some jobs don't have posting dates so try them
        try:
            job_post_date=card.find(class_='date').get_text()
        except:
            job_post_date=' '
        posting_dates.append(job_post_date)
    #locations
        job_location=card.find(class_='location').get_text()
        locations.append(job_location)
#locations
#lets make this dataframe
#declare the empty lists that will become columns
    position_name=[]
    employer=[]
    full_description=[]
#in the future, we can develop a list of keywords that we'll 
  #search postings for, but for now, just return all capitalized
   #words besides common words
    capital_words=[]
    for job_url in job_urls:
    #retrieve job page
        job_page=requests.get(job_url,headers=headers)
    #make job page into BeautifulSoup object
        job_soup=BeautifulSoup(job_page.content,'html.parser')
    #retrieve the job title
        job_position=job_soup.find(class_='icl-u-xs-mb--xs').get_text()
    #retrieve company name from job rating line on page
        job_rating_line=job_soup.find(class_='jobsearch-InlineCompanyRating')
        job_employer=job_rating_line.find(class_='icl-u-lg-mr--sm').get_text()
    #retrieve full job description
        job_descrip=job_soup.find(class_='jobsearch-JobComponent-description').get_text()
    #replace line breaks in description with spaces
        job_descrip.replace('\n',' ')
    #find capitalized words in job description
        capitals=re.findall('([A-Z][a-z]+)', job_descrip)
    #replace commonly capitalized words
        for x in ['The','Our','A','As','On','Using','We', 'In', 'Some']:
            try:
                capitals[:]=(value for value in capitals if value!=x)
            except:
                capitals
    #make capitals into a set instead of a list
        capitals=set(capitals)
        capital_string=', '.join(capitals)
    #append all of the items created to the empty lists from last step
        position_name.append(job_position)
        employer.append(job_employer)
        full_description.append(job_descrip)
        capital_words.append(capitals)
        
#store results in dictionary, then data frame
    import pandas as pd
    result_dict={'Job Title':position_name,
                'Employer':employer,
                'Location':locations,
                'Posting Date':posting_dates, 
                'Posting Url':job_urls,
                'Full Job Description':full_description,
                'Keywords':capital_words
                }
    result_frame=pd.DataFrame(result_dict)
    return(result_frame)

# %%
# Out:
#                    Job Title                                   Employer  \
# 0            Pricing Analyst            GNC - General Nutrition Centers
# 1             Market Analyst                    Carmeuse Lime and Stone
# 2        IT Business Analyst                                  Pepon inc
# 3    Student Records Analyst               The University of Pittsburgh
# 4         Operations Analyst               PNC Financial Services Group
# 5       Freight Rate Analyst                                      Aires
# 6        Jr. Project Analyst                         Grane Hospice Care
# 7   Statistical Data Analyst               The University of Pittsburgh
# 8              SCADA Analyst                Cabot Oil & Gas Corporation
# 9           Planning Analyst  Great Lakes Behavioral Research Institute
# 10        Programmer/Analyst               United States District Court
# 11   Shared Services Analyst            Paragon Asset Recovery Services
# 12        Operations Analyst               PNC Financial Services Group
#
#                                              Location  Posting Date  \
# 0   Pittsburgh, PA 15201 (Central Lawrenceville area)
# 1                                      Pittsburgh, PA
# 2                                      Pittsburgh, PA   4 hours ago
# 3                                      Pittsburgh, PA    9 days ago
# 4   Pittsburgh, PA 15289 (Central Business Distric...     1 day ago
# 5                                Pittsburgh, PA 15276   16 days ago
# 6                                      Fox Chapel, PA    3 days ago
# 7                                      Pittsburgh, PA   14 days ago
# 8                                Pittsburgh, PA 15275    6 days ago
# 9             Pittsburgh, PA 15219 (Middle Hill area)  30+ days ago
# 10                                     Pittsburgh, PA     1 day ago
# 11                                     Pittsburgh, PA    2 days ago
# 12  Pittsburgh, PA 15289 (Central Business Distric...     1 day ago
#
#                                           Posting Url  \
# 0   https://www.indeed.com/viewjob?jk=ba923ce88d20...
# 1   https://www.indeed.com/viewjob?jk=b56e0d79ec34...
# 2   https://www.indeed.com/viewjob?jk=e3e1de7c3972...
# 3   https://www.indeed.com/viewjob?jk=a172d5d7aebf...
# 4   https://www.indeed.com/viewjob?jk=91009db8062e...
# 5   https://www.indeed.com/viewjob?jk=ff172f4f5687...
# 6   https://www.indeed.com/viewjob?jk=16854ba0402e...
# 7   https://www.indeed.com/viewjob?jk=6fec1a95673c...
# 8   https://www.indeed.com/viewjob?jk=ddb0ca22105f...
# 9   https://www.indeed.com/viewjob?jk=bfe4229fbe4f...
# 10  https://www.indeed.com/viewjob?jk=fcdf333dc866...
# 11  https://www.indeed.com/viewjob?jk=2edc3878dda3...
# 12  https://www.indeed.com/viewjob?jk=58ec1f7ac23f...
#
#                                  Full Job Description  \
# 0   The Pricing Analyst will provide wholesale pri...
# 1   Company Description: Carmeuse Lime & Stone bas...
# 2   ContractExperience: 10+ Years business analyst...
# 3   $23,868 - $37,752 a yearStudent Records Analys...
# 4   Position Overview\n\nAt PNC, our people are ou...
# 5   An excellent career opportunity is currently a...
# 6   Jr. Project Analyst Full TimeRIDC Park – Fox C...
# 7   $30,732 - $49,296 a yearStatistical Data Analy...
# 8   JOB FUNCTIONS:1. Support SCADA system administ...
# 9   $45,000 - $60,000 a yearWe are seeking a Plann...
# 10  $50,216 - $81,673 a yearAnnouncement Number: 1...
# 11  Paragon has an immediate opening for a Shared ...
# 12  Position Overview\n\nAt PNC, our people are ou...
#
#                                              Keywords
# 0   {Economics, Master, Bachelor, Maintain, Essent...
# 1   {America, Communication, Market, Perform, Bach...
# 2   {Experience, Strong, Type, Requirements, Busin...
# 3   {Applicable, Student, Not, Classification, Gra...
# 4   {Assesses, At, Attention, Typically, Risk, Ope...
# 5   {Freight, Responsibility, Results, Examine, Ma...
# 6   {New, Bachelor, Information, Analystis, Benefi...
# 7   {Master, Applicable, Other, Plus, Specialist, ...
# 8   {Cyg, Is, Work, Experience, Type, Net, Assist,...
# 9   {Analyzing, Researching, County, Designing, Ba...
# 10  {Minimum, Salary, Grade, Position, Link, Closi...
# 11  {Care, Other, These, About, Benefits, Shared, ...
# 12  {Assesses, At, Attention, Typically, Risk, Ope...
