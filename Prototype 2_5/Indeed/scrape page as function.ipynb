# %%
#define function that scrapes one page at a time and returns a panda dataframe
def scrape_page(page_num):
    import requests  # b_soup_1.py
    import re
    from bs4 import BeautifulSoup
    #spoof the user agent to make page scrapable
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
#define position search term (one word) and location
    position='analyst'
    location='Pittsburgh,+PA'
    page_str=str(page_num)
#url for search query
    url='https://www.indeed.com/jobs?q='+position+'&l='+location+'&start='+page_str
    search_page=requests.get(url,headers=headers)
    search_page
    soup=BeautifulSoup(search_page.content,'html.parser')
    all_cards=soup.find_all(class_='jobsearch-SerpJobCard row result')
#empty list to store job posting urls
    job_urls=[]
#it seems to be easier to pull posting dates and locations from search page, so do that here
    posting_dates=[]
    locations=[]
#iterate through all_cards, extract job posting urls, posting dates, and locations
    for card in all_cards:
    #urls
        job_id=card['data-jk']
        job_url='https://www.indeed.com/viewjob?jk='+job_id
        job_urls.append(job_url)
    #posting dates
    #some jobs don't have posting dates so try them
        try:
            job_post_date=card.find(class_='date').get_text()
        except:
            job_post_date=' '
        posting_dates.append(job_post_date)
    #locations
        job_location=card.find(class_='location').get_text()
        locations.append(job_location)
#locations
#lets make this dataframe
#declare the empty lists that will become columns
    position_name=[]
    employer=[]
    full_description=[]
#in the future, we can develop a list of keywords that we'll 
  #search postings for, but for now, just return all capitalized
   #words besides common words
    capital_words=[]
    for job_url in job_urls:
    #retrieve job page
        job_page=requests.get(job_url,headers=headers)
    #make job page into BeautifulSoup object
        job_soup=BeautifulSoup(job_page.content,'html.parser')
    #retrieve the job title
        job_position=job_soup.find(class_='icl-u-xs-mb--xs').get_text()
    #retrieve company name from job rating line on page
        job_rating_line=job_soup.find(class_='jobsearch-InlineCompanyRating')
        job_employer=job_rating_line.find(class_='icl-u-lg-mr--sm').get_text()
    #retrieve full job description
        job_descrip=job_soup.find(class_='jobsearch-JobComponent-description').get_text()
    #replace line breaks in description with spaces
        job_descrip.replace('\n',' ')
    #find capitalized words in job description
        capitals=re.findall('([A-Z][a-z]+)', job_descrip)
    #replace commonly capitalized words
        for x in ['The','Our','A','As','On','Using','We', 'In', 'Some']:
            try:
                capitals[:]=(value for value in capitals if value!=x)
            except:
                capitals
    #make capitals into a set instead of a list
        capitals=set(capitals)
        capital_string=', '.join(capitals)
    #append all of the items created to the empty lists from last step
        position_name.append(job_position)
        employer.append(job_employer)
        full_description.append(job_descrip)
        capital_words.append(capitals)
        
#store results in dictionary, then data frame
    import pandas as pd
    result_dict={'Job Title':position_name,
                'Employer':employer,
                'Location':locations,
                'Posting Date':posting_dates, 
                'Posting Url':job_urls,
                'Full Job Description':full_description,
                'Keywords':capital_words
                }
    result_frame=pd.DataFrame(result_dict)
    return(result_frame)

# %%
import pandas as pd
df=scrape_page(0)
for x in range(1,10):
    temp=scrape_page(x)
    df=pd.concat([df,temp])

# %%
df
# Out:
#                                          Job Title  \
# 0                                 Business Analyst
# 1                              IT Business Analyst
# 2                         Business Process Analyst
# 6   Position Overview\n\nAt PNC, our people are ou...
# 7   An excellent career opportunity is currently a...
# 8   $50,216 - $81,673 a yearAnnouncement Number: 1...
# 9   $23,868 - $37,752 a yearStudent Records Analys...
# 10  PRIMARY RESPONSIBILITIES OF A DATA ANALYST I:\...
# 11  Company Description: Carmeuse Lime & Stone bas...
# 0   Customer Operations Business Process Analyst\n...
# 1   The Pricing Analyst will provide wholesale pri...
# 2   Jr. Project Analyst Full TimeRIDC Park – Fox C...
# 3   $30,732 - $49,296 a yearStatistical Data Analy...
# 4   Position Overview\n\nAt PNC, our people are ou...
# ..                                                ...
# 6   At ConnectiveRx we simplify how people get and...
# 7   Purpose:\nUPMC Health Plan's Medical Managemen...
# 8   $40,092 - $65,676 a yearFInancial Analyst\nCom...
# 9   PRIMARY RESPONSIBILITIES OF A DATA ANALYST I:\...
# 10  $45,000 - $60,000 a yearWe are seeking a Plann...
# 11  ContractExperience: 10+ Years business analyst...
# 0   Customer Operations Business Process Analyst\n...
# 1   The Pricing Analyst will provide wholesale pri...
# 2   Jr. Project Analyst Full TimeRIDC Park – Fox C...
# 3   $30,732 - $49,296 a yearStatistical Data Analy...
# 4   Position Overview\n\nAt PNC, our people are ou...
# 5   $23,868 - $37,752 a yearStudent Records Analys...
# 6   $50,216 - $81,673 a yearAnnouncement Number: 1...
# 7   An excellent career opportunity is currently a...
# 8   JOB FUNCTIONS:1. Support SCADA system administ...
# 9   Carnegie Mellon University (CMU) is seeking an...
# 10  $45,000 - $60,000 a yearWe are seeking a Plann...
# 11  ContractExperience: 10+ Years business analyst...
# 0   Customer Operations Business Process Analyst\n...
# 1   The Pricing Analyst will provide wholesale pri...
# 2   Jr. Project Analyst Full TimeRIDC Park – Fox C...
# 3   $30,732 - $49,296 a yearStatistical Data Analy...
# 4   Position Overview\n\nAt PNC, our people are ou...
# 5   $23,868 - $37,752 a yearStudent Records Analys...
# 6   $50,216 - $81,673 a yearAnnouncement Number: 1...
# 7   An excellent career opportunity is currently a...
# 8   JOB FUNCTIONS:1. Support SCADA system administ...
# 9   Carnegie Mellon University (CMU) is seeking an...
# 10  $45,000 - $60,000 a yearWe are seeking a Plann...
# 11  ContractExperience: 10+ Years business analyst...
#
#                                              Keywords
# 0   {Assist, Recycling, North, Board, Bachelor, At...
# 1   {Exceptional, Location, Microsoft, No, Contrac...
# 2   {Perform, Supports, Translate, Cases, Microsof...
# 3   {Accounting, Key, Type, National, Analyst, Acc...
# 4   {Assist, Recycling, North, Board, Bachelor, At...
# 5   {Software, Thanks, Hello, Everyone, Type, Data...
# 6   {Systems, Level, Pennsylvania, Cover, Relocati...
# 7   {Systems, Level, Pennsylvania, Cover, Relocati...
# 8   {Intermediate, Tableau, Qualifiers, Bachelor, ...
# 9   {Description, Microsoft, Relocation, Free, Typ...
# 10  {Description, Highmark, Hm, Yes, For, Required...
# 11  {Nondiscrimination, To, At, Accounting, Twitte...
# 12  {Description, Perform, External, Communication...
# 0   {Accounting, Regularly, Bachelor, Economics, A...
# 1   {Exceptional, Location, Microsoft, No, Contrac...
# 2   {Description, Microsoft, Relocation, Free, Typ...
# 3   {Plus, Pennsylvania, Level, Cover, Relocation,...
# 4   {Jr, Level, Main, Harrisburg, Organizing, Bach...
# 5   {Assist, Apply, Microsoft, Susquehanna, Net, C...
# 6   {Solution, Risk, At, Processes, Roles, Firstsi...
# 7   {Negotiate, Microsoft, An, Aires, Demonstrated...
# 8   {Date, Number, Pittsburgh, Job, Grade, Link, O...
# 9   {Rights, Level, Pennsylvania, Cover, Relocatio...
# 10  {Elliott, If, Analyzing, Developing, Attending...
# 11  {Description, Perform, External, Communication...
# 0   {Perform, Supports, Translate, Cases, Microsof...
# 1   {Accounting, Regularly, Bachelor, Economics, A...
# 2   {Jr, Level, Main, Harrisburg, Organizing, Bach...
# 3   {Plus, Pennsylvania, Level, Cover, Relocation,...
# 4   {Solution, Risk, At, Processes, Roles, Firstsi...
# ..                                                ...
# 6   {Assist, Review, Document, At, Formed, Highly,...
# 7   {Complete, Union, Disabilities, Arc, Experienc...
# 8   {Level, Accounting, Key, Inancial, Staff, For,...
# 9   {Elliott, If, Analyzing, Developing, Attending...
# 10  {County, Apply, Incumbent, Location, Youth, Ad...
# 11  {Exceptional, Location, Microsoft, No, Contrac...
# 0   {Perform, Supports, Translate, Cases, Microsof...
# 1   {Accounting, Regularly, Bachelor, Economics, A...
# 2   {Jr, Level, Main, Harrisburg, Organizing, Bach...
# 3   {Plus, Pennsylvania, Level, Cover, Relocation,...
# 4   {Solution, Risk, At, Processes, Roles, Firstsi...
# 5   {Rights, Level, Pennsylvania, Cover, Relocatio...
# 6   {Date, Number, Pittsburgh, Job, Grade, Link, O...
# 7   {Negotiate, Microsoft, An, Aires, Demonstrated...
# 8   {Assist, Apply, Microsoft, Susquehanna, Net, C...
# 9   {Veteran, Therefore, Level, Accounting, Pennsy...
# 10  {County, Apply, Incumbent, Location, Youth, Ad...
# 11  {Exceptional, Location, Microsoft, No, Contrac...
# 0   {Perform, Supports, Translate, Cases, Microsof...
# 1   {Accounting, Regularly, Bachelor, Economics, A...
# 2   {Jr, Level, Main, Harrisburg, Organizing, Bach...
# 3   {Plus, Pennsylvania, Level, Cover, Relocation,...
# 4   {Solution, Risk, At, Processes, Roles, Firstsi...
# 5   {Rights, Level, Pennsylvania, Cover, Relocatio...
# 6   {Date, Number, Pittsburgh, Job, Grade, Link, O...
# 7   {Negotiate, Microsoft, An, Aires, Demonstrated...
# 8   {Assist, Apply, Microsoft, Susquehanna, Net, C...
# 9   {Veteran, Therefore, Level, Accounting, Pennsy...
# 10  {County, Apply, Incumbent, Location, Youth, Ad...
# 11  {Exceptional, Location, Microsoft, No, Contrac...
#
# [121 rows x 7 columns]

# %%
df.toexce
